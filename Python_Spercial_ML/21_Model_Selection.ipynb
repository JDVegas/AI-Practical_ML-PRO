# %% [markdown]
# <h1>21 - Model Selection</h1>
#
# Lien Vidéo tuto: <a href="https://www.youtube.com/watch?v=w_bLGK4Pteo&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=22">PYTHON SKLEARN - MODEL SELECTION : Train_test_split, Cross Validation, GridSearchCV (21/30)</a>
